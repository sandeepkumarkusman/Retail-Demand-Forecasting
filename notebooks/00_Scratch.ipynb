# %% [markdown]
# # Scratch workspace
# Project-generated notebook. It is not an original Kaggle notebook.

# %%
from src.pipeline import run_xyzt_awesome_pipeline
submission = run_xyzt_awesome_pipeline()
submission.head()
