# %% [markdown]
# # Backtesting
# The analyzed Prophet reference notebook reads precomputed CV artifacts. Those artifacts are unavailable, so this notebook documents the limitation rather than fabricating folds.

# %%
from src.backtesting import load_prophet_cv_reference
# Supply the original external CV file path if it becomes available.
