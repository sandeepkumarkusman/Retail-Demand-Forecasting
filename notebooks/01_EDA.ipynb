# %% [markdown]
# # EDA
# Project-generated entry point for inspecting the raw competition data.

# %%
from src.data_loader import load_xyzt_data
train, test, sample_submission = load_xyzt_data()
train.describe()
