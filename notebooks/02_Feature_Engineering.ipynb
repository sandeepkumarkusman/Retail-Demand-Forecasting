# %% [markdown]
# # Feature Engineering
# Project-generated XYZT feature walkthrough.

# %%
from src.data_loader import load_xyzt_data
from src.features import expand_xyzt_date_features
train, _, _ = load_xyzt_data()
features = expand_xyzt_date_features(train)
features.head()
