# %% [markdown]
# # Presentation Walkthrough
# Run the verified XYZT solution from raw CSVs to an index-free submission.

# %%
from src.pipeline import run_active_solution
submission = run_active_solution()
submission.head()
