# %% [markdown]
# # Baselines
# The fallback baseline is project infrastructure, not a Kaggle notebook reproduction.

# %%
from src.pipeline import run_unavailable_artifact_fallback_pipeline
fallback_submission = run_unavailable_artifact_fallback_pipeline()
fallback_submission.head()
