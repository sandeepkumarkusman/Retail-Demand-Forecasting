# %% [markdown]
# # Error Analysis
# Project-generated placeholder. Competition test labels are unavailable, so test-set error metrics cannot be calculated.

# %%
import pandas as pd
submission = pd.read_csv('outputs/submission.csv')
submission.describe()
