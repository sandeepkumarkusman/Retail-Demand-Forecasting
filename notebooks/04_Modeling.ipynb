# %% [markdown]
# # Modeling
# Project-generated walkthrough of the verified XYZT model path.

# %%
from src.data_loader import load_xyzt_data
from src.features import expand_xyzt_date_features
from src.train import fit_xyzt_awesome_model
train, _, _ = load_xyzt_data()
model = fit_xyzt_awesome_model(expand_xyzt_date_features(train))
model.keys()
